# %%
# !pip install pandas==1.3
# !pip install tqdm==4.61.2
import os
import pandas as pd
from tqdm import tqdm, notebook
notebook.tqdm().pandas()
# %load_ext autoreload

import twee_utils
import importlib
import tqdm, pandas
importlib.reload(twee_utils)
importlib.reload(tqdm)
importlib.reload(pandas)
# Out:
# 0it [00:00, ?it/s]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <module 'pandas' from '/Users/alex/anaconda3/lib/python3.7/site-packages/pandas/__init__.py'>

# %%
downloads = "./game_downloads"

# %%
try_unzip('./game_downloads/breengrub.zip', './game_html/temp')
! ls ./game_html/temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b01003641a82> in <module>
# ----> 1 try_unzip('./game_downloads/breengrub.zip', './game_html/temp')
#       2 get_ipython().system(' ls ./game_html/temp')
#
# NameError: name 'try_unzip' is not defined

# %%
import twee_utils
import importlib
import tqdm, pandas
importlib.reload(twee_utils)
importlib.reload(tqdm)
importlib.reload(pandas)

# Test that we can get a zip, a folder, and an html file this way
html1, html_files1 = twee_utils.get_html_source('./game_downloads/breengrub.zip')
html2, html_files2 = twee_utils.get_html_source('./game_downloads/Iron Kid Interactive Story/')
html3, html_files3 = twee_utils.get_html_source('./game_downloads/3_Garde_Final.html')
print(html_files1, html_files2, html_files3)

# %%
# !ls ./game_downloads/

# %%
# %autoreload 2
import twee_utils
import importlib
importlib.reload(twee_utils)

twine = pd.DataFrame({'file': os.listdir(downloads)})
twine['path'] = twine.file.apply(lambda x: os.path.join(downloads, x))
twine['filetype'] = twine.file.apply(lambda x: x.split('.')[-1] if '.' in x else 'unk')
twine = twine[~twine.filetype.isin(('exe', 'quest', 'apk'))]
twine['html'] = twine.path.progress_apply(lambda x: twee_utils.get_html_source(x))
# Out:
#   0%|          | 0/512 [00:00<?, ?it/s]
#                                                 file  \
# 0                                             nw.dll
# 1            November 9th, 2015 - Jan 26th, 2016.zip
# 2                                GraySkiesAlpha.html
# 3  Il Bus - A Game by Eta Beta ScS (2021 - Turin,...
# 4                                              pnacl
#
#                                                 path filetype  \
# 0                            ./game_downloads/nw.dll      dll
# 1  ./game_downloads/November 9th, 2015 - Jan 26th...      zip
# 2               ./game_downloads/GraySkiesAlpha.html     html
# 3  ./game_downloads/Il Bus - A Game by Eta Beta S...     html
# 4                             ./game_downloads/pnacl      unk
#
#                                                 html
# 0
# 1
# 2  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...
# 3  <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
# 4

# %%
twine.to_pickle('twine.pkl')
twine.head(30)
# Out:
#                                                  file  \
# 0                                              nw.dll
# 1             November 9th, 2015 - Jan 26th, 2016.zip
# 2                                 GraySkiesAlpha.html
# 3   Il Bus - A Game by Eta Beta ScS (2021 - Turin,...
# 4                                               pnacl
# 5        Casos Extravagantes Poco Complicados (2).zip
# 6                          THIS FOLDER IS HAUNTED.zip
# 7                                       BionicSun.zip
# 8                                   SpringThing18.zip
# 9                          Death at Nine to Five.html
# 10                                        angelic.zip
# 11                                     oh and two.rar
# 12                                      breengrub.zip
# 13                               nacl_irt_x86_64.nexe
# 14                         A Bathroom Myth final.html
# 15                                  DroidSansMono.ttf
# 16                                BEACH COVE(N) AHEAD
# 17      TheSaintsofHorsesQuestfortheTraitorSaint.html
# 19                         A_Month_in_Z32-LDJAM32.zip
# 20                                        The Domovoi
# 21                                                DTT
# 22                          02 Clash of Androids.html
# 23                             rituals_catharsis.html
# 24               Seven Second Sandwich Simulator.html
# 25                         Intertwined Alpha V1.1.zip
# 26                                       Hammock.html
# 27                       More Than Monsters demo.html
# 28                                Balance of Souls.7z
# 29                               LifelessGalaxyEN.rar
# 30               The Consumption of the Disciple.html
#
#                                                  path filetype  \
# 0                             ./game_downloads/nw.dll      dll
# 1   ./game_downloads/November 9th, 2015 - Jan 26th...      zip
# 2                ./game_downloads/GraySkiesAlpha.html     html
# 3   ./game_downloads/Il Bus - A Game by Eta Beta S...     html
# 4                              ./game_downloads/pnacl      unk
# 5   ./game_downloads/Casos Extravagantes Poco Comp...      zip
# 6         ./game_downloads/THIS FOLDER IS HAUNTED.zip      zip
# 7                      ./game_downloads/BionicSun.zip      zip
# 8                  ./game_downloads/SpringThing18.zip      zip
# 9         ./game_downloads/Death at Nine to Five.html     html
# 10                       ./game_downloads/angelic.zip      zip
# 11                    ./game_downloads/oh and two.rar      rar
# 12                     ./game_downloads/breengrub.zip      zip
# 13              ./game_downloads/nacl_irt_x86_64.nexe     nexe
# 14        ./game_downloads/A Bathroom Myth final.html     html
# 15                 ./game_downloads/DroidSansMono.ttf      ttf
# 16               ./game_downloads/BEACH COVE(N) AHEAD      unk
# 17  ./game_downloads/TheSaintsofHorsesQuestfortheT...     html
# 19        ./game_downloads/A_Month_in_Z32-LDJAM32.zip      zip
# 20                       ./game_downloads/The Domovoi      unk
# 21                               ./game_downloads/DTT      unk
# 22         ./game_downloads/02 Clash of Androids.html     html
# 23            ./game_downloads/rituals_catharsis.html     html
# 24  ./game_downloads/Seven Second Sandwich Simulat...     html
# 25        ./game_downloads/Intertwined Alpha V1.1.zip      zip
# 26                      ./game_downloads/Hammock.html     html
# 27      ./game_downloads/More Than Monsters demo.html     html
# 28               ./game_downloads/Balance of Souls.7z       7z
# 29              ./game_downloads/LifelessGalaxyEN.rar      rar
# 30  ./game_downloads/The Consumption of the Discip...     html
#
#                                                  html
# 0
# 1
# 2   ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...
# 3   <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
# 4
# 5
# 6
# 7   <!DOCTYPE html>\n<html data-init="no-js">\n<he...
# 8
# 9   <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
# 10
# 11
# 12  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...
# 13
# 14  <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
# 15
# 16  <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
# 17  <!DOCTYPE html>\n<!--[if lte IE 8]> <html clas...
# 19  <!DOCTYPE html>\n<!--[if lte IE 8]> <html clas...
# 20  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...
# 21  <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
# 22  <!DOCTYPE html>\n<html data-init="no-js">\n<he...
# 23  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 24  <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
# 25
# 26  <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
# 27  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...
# 28
# 29
# 30  <!DOCTYPE html>\n<html data-init="no-js">\n<he...

# %% [markdown]
# ## Load saved twine data

# %%
import pandas as pd
twine = pd.read_pickle('twine.pkl')

# %%
valid_twine = twine[twine.html != '']
valid_twine = valid_twine.reset_index()
valid_twine
# Out:
#      index                                               file  \
# 0        2                                GraySkiesAlpha.html
# 1        3  Il Bus - A Game by Eta Beta ScS (2021 - Turin,...
# 2        7                                      BionicSun.zip
# 3        9                         Death at Nine to Five.html
# 4       12                                      breengrub.zip
# ..     ...                                                ...
# 268    503                          Impact Jam - The Game.zip
# 269    505             That Time You Found A Missing Cat.html
# 270    506                                          Five.html
# 271    512                             Famous Last Words.html
# 272    517                                  A Good Death.html
#
#                                                   path filetype  \
# 0                 ./game_downloads/GraySkiesAlpha.html     html
# 1    ./game_downloads/Il Bus - A Game by Eta Beta S...     html
# 2                       ./game_downloads/BionicSun.zip      zip
# 3          ./game_downloads/Death at Nine to Five.html     html
# 4                       ./game_downloads/breengrub.zip      zip
# ..                                                 ...      ...
# 268         ./game_downloads/Impact Jam - The Game.zip      zip
# 269  ./game_downloads/That Time You Found A Missing...     html
# 270                         ./game_downloads/Five.html     html
# 271            ./game_downloads/Famous Last Words.html     html
# 272                 ./game_downloads/A Good Death.html     html
#
#                                                   html
# 0    ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...
# 1    <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
# 2    <!DOCTYPE html>\n<html data-init="no-js">\n<he...
# 3    <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
# 4    ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...
# ..                                                 ...
# 268  <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
# 269  <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
# 270  <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
# 271  <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
# 272  <!DOCTYPE html>\n<html>\n<head>\n<meta charset...
#
# [273 rows x 5 columns]

# %%
valid_twine['is_untweeable'] = valid_twine.html.apply(lambda x: twee_utils.is_untweeable(x))
valid_twine
valid_twine[valid_twine.is_untweeable]
tweeable_twine = valid_twine[valid_twine.is_untweeable]
tweeable_twine
# Out:
#      index                                           file  \
# 0        2                            GraySkiesAlpha.html
# 4       12                                  breengrub.zip
# 7       17  TheSaintsofHorsesQuestfortheTraitorSaint.html
# 8       19                     A_Month_in_Z32-LDJAM32.zip
# 9       20                                    The Domovoi
# ..     ...                                            ...
# 245    449                           Cabin Fever Complete
# 250    460                         Lights Out Please.html
# 255    471                                rocketjump.html
# 266    500                           colors of sound.html
# 267    502                           theactofwriting.html
#
#                                                   path filetype  \
# 0                 ./game_downloads/GraySkiesAlpha.html     html
# 4                       ./game_downloads/breengrub.zip      zip
# 7    ./game_downloads/TheSaintsofHorsesQuestfortheT...     html
# 8          ./game_downloads/A_Month_in_Z32-LDJAM32.zip      zip
# 9                         ./game_downloads/The Domovoi      unk
# ..                                                 ...      ...
# 245              ./game_downloads/Cabin Fever Complete      unk
# 250            ./game_downloads/Lights Out Please.html     html
# 255                   ./game_downloads/rocketjump.html     html
# 266              ./game_downloads/colors of sound.html     html
# 267              ./game_downloads/theactofwriting.html     html
#
#                                                   html  is_untweeable
# 0    ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 4    ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 7    <!DOCTYPE html>\n<!--[if lte IE 8]> <html clas...           True
# 8    <!DOCTYPE html>\n<!--[if lte IE 8]> <html clas...           True
# 9    ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# ..                                                 ...            ...
# 245  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 250  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 255  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...           True
# 266  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 267  <!DOCTYPE html>\n<!--[if lte IE 8]> <html clas...           True
#
# [82 rows x 6 columns]

# %%
def untwee(s):
    html = s['html']
    file = twee_utils.make_temp_file(html)
    twee, error = twee_utils.untwee(file)
    twee_utils.delete_temp_file(file)
    return twee, error

# head = valid_twine.head(5)

tweeable_twine[['twee', 'twee_error']] = tweeable_twine.progress_apply(untwee, axis=1, result_type='expand')
tweeable_twine
# head['twee'], head['twee_error'] = valid_twine.html.apply(
#     (lambda x: untwee(x)), result_type='expand'
# ).T.values
# Out:
#   0%|          | 0/82 [00:00<?, ?it/s]
# /Users/alex/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#      index                                           file  \
# 0        2                            GraySkiesAlpha.html
# 4       12                                  breengrub.zip
# 7       17  TheSaintsofHorsesQuestfortheTraitorSaint.html
# 8       19                     A_Month_in_Z32-LDJAM32.zip
# 9       20                                    The Domovoi
# ..     ...                                            ...
# 245    449                           Cabin Fever Complete
# 250    460                         Lights Out Please.html
# 255    471                                rocketjump.html
# 266    500                           colors of sound.html
# 267    502                           theactofwriting.html
#
#                                                   path filetype  \
# 0                 ./game_downloads/GraySkiesAlpha.html     html
# 4                       ./game_downloads/breengrub.zip      zip
# 7    ./game_downloads/TheSaintsofHorsesQuestfortheT...     html
# 8          ./game_downloads/A_Month_in_Z32-LDJAM32.zip      zip
# 9                         ./game_downloads/The Domovoi      unk
# ..                                                 ...      ...
# 245              ./game_downloads/Cabin Fever Complete      unk
# 250            ./game_downloads/Lights Out Please.html     html
# 255                   ./game_downloads/rocketjump.html     html
# 266              ./game_downloads/colors of sound.html     html
# 267              ./game_downloads/theactofwriting.html     html
#
#                                                   html  is_untweeable  \
# 0    ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 4    ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 7    <!DOCTYPE html>\n<!--[if lte IE 8]> <html clas...           True
# 8    <!DOCTYPE html>\n<!--[if lte IE 8]> <html clas...           True
# 9    ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# ..                                                 ...            ...
# 245  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 250  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 255  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...           True
# 266  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 267  <!DOCTYPE html>\n<!--[if lte IE 8]> <html clas...           True
#
#                                                   twee twee_error
# 0    b':: Debug Silo\n<<set $detkey to "true">>\n\n...       None
# 4    b':: pour out onto the floor.\nYou <<replace "...       None
# 7    b':: saint mercury [Twine.image]\ndata:image/j...       None
# 8    b':: Mountain [coreLoop explore]\n<<set $mount...       None
# 9    b':: Start2 [start]\n<<stopallsound>>\n<<fadei...       None
# ..                                                 ...        ...
# 245  b':: fireplace3\n<<set $awareness += 2>><<set ...       None
# 250  b':: But why should I have to suffer alone? [m...       None
# 255  b':: Ralph Lauren\nYou tweet your succcess sto...       None
# 266  b':: love\nplease tell me i still matter and <...       None
# 267  b':: walk\n9 kilometres.\n\nAway from the more...       None
#
# [82 rows x 8 columns]

# %%
tweeable_twine
# Out:
#      index                                           file  \
# 0        2                            GraySkiesAlpha.html
# 4       12                                  breengrub.zip
# 7       17  TheSaintsofHorsesQuestfortheTraitorSaint.html
# 8       19                     A_Month_in_Z32-LDJAM32.zip
# 9       20                                    The Domovoi
# ..     ...                                            ...
# 245    449                           Cabin Fever Complete
# 250    460                         Lights Out Please.html
# 255    471                                rocketjump.html
# 266    500                           colors of sound.html
# 267    502                           theactofwriting.html
#
#                                                   path filetype  \
# 0                 ./game_downloads/GraySkiesAlpha.html     html
# 4                       ./game_downloads/breengrub.zip      zip
# 7    ./game_downloads/TheSaintsofHorsesQuestfortheT...     html
# 8          ./game_downloads/A_Month_in_Z32-LDJAM32.zip      zip
# 9                         ./game_downloads/The Domovoi      unk
# ..                                                 ...      ...
# 245              ./game_downloads/Cabin Fever Complete      unk
# 250            ./game_downloads/Lights Out Please.html     html
# 255                   ./game_downloads/rocketjump.html     html
# 266              ./game_downloads/colors of sound.html     html
# 267              ./game_downloads/theactofwriting.html     html
#
#                                                   html  is_untweeable  \
# 0    ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 4    ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 7    <!DOCTYPE html>\n<!--[if lte IE 8]> <html clas...           True
# 8    <!DOCTYPE html>\n<!--[if lte IE 8]> <html clas...           True
# 9    ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# ..                                                 ...            ...
# 245  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 250  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 255  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...           True
# 266  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 267  <!DOCTYPE html>\n<!--[if lte IE 8]> <html clas...           True
#
#                                                   twee twee_error
# 0    b':: Debug Silo\n<<set $detkey to "true">>\n\n...       None
# 4    b':: pour out onto the floor.\nYou <<replace "...       None
# 7    b':: saint mercury [Twine.image]\ndata:image/j...       None
# 8    b':: Mountain [coreLoop explore]\n<<set $mount...       None
# 9    b':: Start2 [start]\n<<stopallsound>>\n<<fadei...       None
# ..                                                 ...        ...
# 245  b':: fireplace3\n<<set $awareness += 2>><<set ...       None
# 250  b':: But why should I have to suffer alone? [m...       None
# 255  b':: Ralph Lauren\nYou tweet your succcess sto...       None
# 266  b':: love\nplease tell me i still matter and <...       None
# 267  b':: walk\n9 kilometres.\n\nAway from the more...       None
#
# [82 rows x 8 columns]

# %%
tweeable_twine.twee = tweeable_twine.twee.str.decode("utf-8")
# Out:
# /Users/alex/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# ## TODO : Fix is_valid_twee

# %%
tweeable_twine['valid_twee'] = tweeable_twine.twee.apply(twee_utils.is_valid_twee)
tweeable_twine
# Out:
#      index                                           file  \
# 0        2                            GraySkiesAlpha.html
# 4       12                                  breengrub.zip
# 7       17  TheSaintsofHorsesQuestfortheTraitorSaint.html
# 8       19                     A_Month_in_Z32-LDJAM32.zip
# 9       20                                    The Domovoi
# ..     ...                                            ...
# 245    449                           Cabin Fever Complete
# 250    460                         Lights Out Please.html
# 255    471                                rocketjump.html
# 266    500                           colors of sound.html
# 267    502                           theactofwriting.html
#
#                                                   path filetype  \
# 0                 ./game_downloads/GraySkiesAlpha.html     html
# 4                       ./game_downloads/breengrub.zip      zip
# 7    ./game_downloads/TheSaintsofHorsesQuestfortheT...     html
# 8          ./game_downloads/A_Month_in_Z32-LDJAM32.zip      zip
# 9                         ./game_downloads/The Domovoi      unk
# ..                                                 ...      ...
# 245              ./game_downloads/Cabin Fever Complete      unk
# 250            ./game_downloads/Lights Out Please.html     html
# 255                   ./game_downloads/rocketjump.html     html
# 266              ./game_downloads/colors of sound.html     html
# 267              ./game_downloads/theactofwriting.html     html
#
#                                                   html  is_untweeable  \
# 0    ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 4    ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 7    <!DOCTYPE html>\n<!--[if lte IE 8]> <html clas...           True
# 8    <!DOCTYPE html>\n<!--[if lte IE 8]> <html clas...           True
# 9    ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# ..                                                 ...            ...
# 245  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 250  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 255  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...           True
# 266  ﻿<!DOCTYPE html>\n<!--[if lte IE 8]><html clas...           True
# 267  <!DOCTYPE html>\n<!--[if lte IE 8]> <html clas...           True
#
#                                                   twee twee_error  valid_twee
# 0    :: Debug Silo\n<<set $detkey to "true">>\n\n<<...       None       False
# 4    :: pour out onto the floor.\nYou <<replace "dr...       None       False
# 7    :: saint mercury [Twine.image]\ndata:image/jpg...       None       False
# 8    :: Mountain [coreLoop explore]\n<<set $mountai...       None       False
# 9    :: Start2 [start]\n<<stopallsound>>\n<<fadeins...       None       False
# ..                                                 ...        ...         ...
# 245  :: fireplace3\n<<set $awareness += 2>><<set $f...       None       False
# 250  :: But why should I have to suffer alone? [man...       None       False
# 255  :: Ralph Lauren\nYou tweet your succcess story...       None       False
# 266  :: love\nplease tell me i still matter and <<c...       None       False
# 267  :: walk\n9 kilometres.\n\nAway from the more s...       None       False
#
# [82 rows x 9 columns]

# %% [markdown]
# ## Get Passages

# %%
importlib.reload(twee_utils)
passages = tweeable_twine.twee.apply(lambda x: [x for x in twee_utils.split_passages(x)]).explode()
# passages = tweeable_twine['twee']
passages = passages.reset_index()

# %%
pd.set_option('max_colwidth', 250)
print(passages.size)
passages.sample(100)
# Out:
# 21568
#       index  \
# 9836    233
# 6482    139
# 5841    120
# 8129    161
# 9595    225
# ...     ...
# 1055     15
# 6279    127
# 5510    120
# 2757     53
# 9684    227
#
#                                                                                                                                                                                                                                                            twee
# 9836  ::real people.\n<<if $p16 is false>><<set $count += 1>><<set $p16 = true>><<endif>>Liam never stopped apologizing.\n\nWhatever weapon the raiders were using could melt metal and plastic composite. They'd burned a hole straight through one of the ...
# 6482  ::car214losesteal\n<<set $health -= 7>>You look around the room and choose a likely philosopher -- a man huge and muscled. You reach into his pocket, searching for bombdrugs, but his spins, eyes furious. A huge fist cracks against your ear and yo...
# 5841  ::Thank the little man and ascend\nYou thank the little man cordially by the hand and ascend.\n\nWhen you are half-way up the spiral staircase you hear the muffled sound of screaming and maniacal laughter echoing from below. You decide to [[conti...
# 8129                                                                                                                                                                                           ::gasp\nSuddenly you feel air escape your [[lungs...|question2]]
# 9595  ::2R [Blackout]\nThis door is decorated with a cartoon duck ornament. You open the door and walk inside. Something crashes and falls. You close the door shut and now you're stuck in the darkness of a stranger's bathroom. They might be family but ...
# ...                                                                                                                                                                                                                                                         ...
# 1055  ::prologue12\n"Oh, look who's got some backbone." Dhaval tosses his cigarette down and smashes it into the grass with his heel. "Don't worry about him."\n\nNow's when Stirling decides to pipe up again. "Really, it's okay! Dhaval would never hurt ...
# 6279  ::blood price\nYou imagine him <<replace "dying.">>mixing the <<replace "pyroglycerine.">>chemicals, packing the bomb <<replace "with explosive.">>with explosive.\n\nYou saw this experiment done once, years ago. <<replace "Only once.">>Only once....
# 5510  ::There is no escape.\nLocked in a cell, your ears and nose stopped up with feathers and inordinately sticky, you cry yourself to sleep.\n\nEven if Prince Prospero were inclined to help you, he is unable, having perished from the plague the night...
# 2757  ::Room\nHelga put her purchase down on the bed and then undid her armour. In the bar to the front of the inn she could <<replace>>hear new customers entering.<<gains>> Her keen senses could pick out at least five of them. They were armed.<<endrep...
# 9684                                                                                                     ::theback\nYou go into the dishroom and throw on an apron.\n\nThe dirties from the brunch rush are already piled high.\n\n[[Time to get to it.|dish1]]
#
# [100 rows x 2 columns]

# %%
passages
# Out:
#        index  \
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 10779    267
# 10780    267
# 10781    267
# 10782    267
# 10783    267
#
#                                                                                                                                                                                                                                                             twee
# 0                                                                                                                                                                        ::Debug Silo\n<<set $detkey to "true">>\n\n<<set $poweron to "true">>\n\n[[Test|silos]]
# 1                 ::officeupstairs\nHalf of the building has collapsed. To your left is a large locker room, with numbers ranging from 100 to 250\n\nOpen locker number <<textinput $lockernum [[Check locker|officelocker]]>>\n\n[[Return to Lobby|officearmy]]
# 2      ::redsfinal\n<<if $healedrads is "false">>\nThe radiation sickness has taken to much of a toll on your body. You collapse as your organs shutdown. And you were so close. \n\n<<else>>\nYou head up a staircase into Reds base. You reach a small meta...
# 3      ::SouthA1\nYou walk for several miles before reaching the mountains. You could try and go through them, but it would be at least a weeks trip through them. You'd die before you made it across. \n\n[[Go North|redexit]]\n\n[[Go through the mountain...
# 4      ::opheimletin\n"Name and Purpose! Tell or leave."\n\n[["My name is <<print $PlayerName>> I'm just passing through on my way north"|opheimpass]]\n\n[["Names LetMeIn and I'm here to beat up curious rat faced assholes"|opheimasshole]]\n\n[[Go North|...
# ...                                                                                                                                                                                                                                                          ...
# 10779  ::postscript\nThis twine was written in an half an hour or so.\n\nI'd like to thank the following twitter users:\n\n@richardgoodness for helping me getting back into writing and giving me encouragement to keep on writing.\n\n@F0lis for being ther...
# 10780                                 ::impatient\nInternet is wrecking your attention span.\n\nWhy am i still writing this?\n\nI wanna do something else.\n\nTWEETS WAITING\n\nSTATUSSES TO LIKE.\n\nWhat have we all become? We're all sons of [[marketers|3]]
# 10781                                                        ::opinion\nThere are many things to be opinionated about:\n\nGender issues\nVideo games\nPolitics\nNews\nSocial media, heck even how to pay you phone bill is something to [[write|writing]] about.
# 10782  ::software\nWith each update.\n\nThe support for older files disappears.\n\nSometimes they keep a copy of the older version of the software on some godforsaken old model computer just so that the contents could be read.\n\nBut, if you're so hell ...
# 10783                                                                                                                                                                                                                                         ::untitled passage
#
# [10784 rows x 2 columns]

# %%
# Rename twee -> passage
if 'twee' in passages:
    passages['passage'] = passages['twee']
    del passages['twee']
print(passages.shape)

passages['char_count'] = passages.passage.apply(len)

# Cut out the long passages
passages = passages[passages.char_count < 1024]
print('without long passages', passages.shape)

# Clean the twee - for some reason this takes a long time
passages['passage'] = passages.passage.progress_apply(twee_utils.clean_images)

# Split into lines
# TODO for some reason this doubles the number of passages
passages['lines'] = passages.passage.apply(twee_utils.split_lines)
passages['line_count'] = passages.lines.apply(len)
passages['first_line'] = passages.lines.apply(lambda x: (x[0] if x else ''))
if 'lines' in passages:
    del passages['lines']

# Drop Duplicates
passages.drop_duplicates(subset=['passage'])
print(passages.shape)
passages.sample(20)
# Out:
# (10784, 2)
# without long passages (8877, 3)
#   0%|          | 0/8877 [00:00<?, ?it/s]
# (8877, 5)
# /Users/alex/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#       index  \
# 9407    221
# 559       7
# 4814    120
# 2225     46
# 933       9
# 8926    189
# 7313    139
# 5773    120
# 3518     59
# 4687    112
# 8710    182
# 4747    117
# 7423    139
# 847       7
# 4031     83
# 2708     50
# 2071     31
# 4208     84
# 2051     31
# 3131     59
#
#                                                                                                                                                                                                                                                         passage  \
# 9407                                                                                         ::chooseascetic\n<<set $inv = {\nclass: 2,\nclassname: "ascetic",\narvels: 3,\nhardbite: 8,\nsurits: 12,\nweapon: "calen",\n}>>You are the Ascetic.\n\n<<landing>>
# 559   ::KeeperWithSil [OW]\n\n\nYou examine a Geoglyph in front of you. It is as big as a soccer field, with shallow depressions carved into the turf and filled back to the brim with white chalk. Most of the lines form a stylized Horse, but a few veer ...
# 4814  ::Yes6\nJust as you complete the diagnostic form you hear a loud bellowing and whooping come from the door across from where you entered this curious asylum.\n\nAll the assembled party, including Mr. Maillard, shrink within their seats to sit qui...
# 2225  ::event3d2_accept\nThe newspapers are shoved into your hands and you are suddenly alone.\n\n<<replace "Examine the stack of newspapers">>You look through the newspapers. At first they appear to be an ordinary stack of newspapers from tomorrow, bu...
# 933                                                                                                                                   ::StorySettings\njquery:off\nhash:off\nbookmark:off\nmodernizr:off\nundo:off\nobfuscate:off\nexitprompt:off\nblankcss:off
# 8926  ::2.1\n<<fadeinsound $wind1 >>\n\nFifty years ago, only a child, you encountered a qalupalik in the dark season, as your mother had hoped you never would.\n\n<<timedinsert 2s>>She slowly pulls herself onto the floe. You can't turn your head away....
# 7313                                             ::car1winattack\n<<set $bombdrugs += 1>>The members of One Sync swing their guitars, but they fall easily to your <<print $currentweapon.name>>. You escape with few wounds!<<updateweapon>>\n\n<<dropweapon>>
# 5773                                                                                                                                                                             ::o+`      \n       `/+/:+o+oh+/:`             `:hh+:``         `///+hyhmNmo+/
# 3518  ::I...\nYou hadn't thought of that... what if this catastrophe wasn't the result of any external force? What if she's right?\n\nYou thank the woman and apologize for your earlier behavior and start to head out the door.\n\n"Wait" she says "take t...
# 4687  ::CSS Phobos [stylesheet phobos]\nhtml {\n  background: fixed, white;\n  background-size: cover;\n  min-height: 100%;\n  height:100%;\n}\nbody {\n  background-color: white;\n  background-attachment: fixed;\n  margin: 0;\n  padding: 0% 15% 0% 5em;...
# 8710  ::explains the third game\n"For this game, there will be 1 silver starting in the pot, each person will take turns either taking the money or passing. If they take the money, the game ends. If they pass, however, 1 more silver will be added to th...
# 4747  ::go\nyou can <<cyclinglink "act" "draw" "paint" "cook" "write" "teach" "dance" "translate" "read" "open a store" "start a food truck" "train dogs" "become an astronomer" "become a physicist" "study history" "become a marine biologist" "grow vege...
# 7423             ::car1winsteal\n<<set $bombdrugs += 15>>While the boy band members are arguing about who gets to use their single surviving haircomb next, you sneak around behind them and steal a LOT of bombdrugs.\n\n[[Onward, to the next car.|trainhub]]
# 847   ::Rotate [OW]\n\n\nAs you turn the model, you get a sense of vertigo. It seems to fold out from a simple cube to an octagonal prism, with a tetrahedroid somewhere in-between the two forms. You can't seem to figure out what's inside and what's out...
# 4031                                                                                                                                                                                                            ::passage2\n\n\n\n\n[[through forums|passage3]]
# 2708  ::escapekitchen\nYou stand in your bedroom, surrounded by all of your familiar things: your bookshelves, your fantasy art posters, that pile of dirty flip-flops. Even Snow Pea is there, muddier than ever and covered in burrs. He wags his tail and...
# 2071                                                                                                            ::LONELINESS\nLONELINESS \n\n\nSadness because one has no friends or company.\n"Feelings of depression and loneliness."\n\n\n[[(<)|previous()]]
# 4208  ::the confusion comes on again. [book]\nthe presence of rodneyness, <<insert "pull">>ed back into a webway of portals across my body,<<gains>> across the body of the mountain on which i ski,<<gains>> across rodney’s body back at the [[lodge]].<<e...
# 2051  ::next19\nYou go back inside and things start to intensify. The lights in the hallway are vibrating, pulsing in waves. The letters on your phone jiggle, your computer screen is plastered with runtime errors. By the second hour, it's like you're d...
# 3131                                                                                                                        ::lights\nYou find the lightswitch and flip it. Finally you can see the bathroom around you. Your eyes are drawn to the [[mirror]].
#
#       char_count  line_count                              first_line
# 9407         152          11                         ::chooseascetic
# 559          554          12                    ::KeeperWithSil [OW]
# 4814         521           8                                  ::Yes6
# 2225         468           8                       ::event3d2_accept
# 933          113           9                         ::StorySettings
# 8926         704           6                                   ::2.1
# 7313         203           4                         ::car1winattack
# 5773          77           2                             ::o+`
# 3518         492           9                                  ::I...
# 4687         593          34        ::CSS Phobos [stylesheet phobos]
# 8710         584           6               ::explains the third game
# 4747         756           4                                    ::go
# 7423         235           4                          ::car1winsteal
# 847          427           8                           ::Rotate [OW]
# 4031          42           6                              ::passage2
# 2708         368           4                         ::escapekitchen
# 2071         135           9                            ::LONELINESS
# 4208         255           2  ::the confusion comes on again. [book]
# 2051         654           9                                ::next19
# 3131         130           2                                ::lights

# %%
importlib.reload(twee_utils)
passages['passage'] = passages.passage.apply(twee_utils.prepare_for_generation)
passages
# Out:
# /Users/alex/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#        index  \
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 10779    267
# 10780    267
# 10781    267
# 10782    267
# 10783    267
#
#                                                                                                                                                                                                                                                          passage  \
# 0                                                                                                                                      <|BG|>::Debug Silo<|NL|><<set $detkey to "true">><|NL|><|NL|><<set $poweron to "true">><|NL|><|NL|>[[Test|silos]]<|EF|>\n
# 1      <|BG|>::officeupstairs<|NL|>Half of the building has collapsed. To your left is a large locker room, with numbers ranging from 100 to 250<|NL|><|NL|>Open locker number <<textinput $lockernum [[Check locker|officelocker]]>><|NL|><|NL|>[[Return to ...
# 2      <|BG|>::redsfinal<|NL|><<if $healedrads is "false">><|NL|>The radiation sickness has taken to much of a toll on your body. You collapse as your organs shutdown. And you were so close. <|NL|><|NL|><<else>><|NL|>You head up a staircase into Reds ba...
# 3      <|BG|>::SouthA1<|NL|>You walk for several miles before reaching the mountains. You could try and go through them, but it would be at least a weeks trip through them. You'd die before you made it across. <|NL|><|NL|>[[Go North|redexit]]<|NL|><|NL|...
# 4      <|BG|>::opheimletin<|NL|>"Name and Purpose! Tell or leave."<|NL|><|NL|>[["My name is <<print $PlayerName>> I'm just passing through on my way north"|opheimpass]]<|NL|><|NL|>[["Names LetMeIn and I'm here to beat up curious rat faced assholes"|ophe...
# ...                                                                                                                                                                                                                                                          ...
# 10779  <|BG|>::postscript<|NL|>This twine was written in an half an hour or so.<|NL|><|NL|>I'd like to thank the following twitter users:<|NL|><|NL|>@richardgoodness for helping me getting back into writing and giving me encouragement to keep on writing...
# 10780  <|BG|>::impatient<|NL|>Internet is wrecking your attention span.<|NL|><|NL|>Why am i still writing this?<|NL|><|NL|>I wanna do something else.<|NL|><|NL|>TWEETS WAITING<|NL|><|NL|>STATUSSES TO LIKE.<|NL|><|NL|>What have we all become? We're all s...
# 10781              <|BG|>::opinion<|NL|>There are many things to be opinionated about:<|NL|><|NL|>Gender issues<|NL|>Video games<|NL|>Politics<|NL|>News<|NL|>Social media, heck even how to pay you phone bill is something to [[write|writing]] about.<|EF|>\n
# 10782  <|BG|>::software<|NL|>With each update.<|NL|><|NL|>The support for older files disappears.<|NL|><|NL|>Sometimes they keep a copy of the older version of the software on some godforsaken old model computer just so that the contents could be read.<...
# 10783                                                                                                                                                                                                                           <|BG|>::untitled passage<|EF|>\n
#
#        char_count  line_count          first_line
# 0              82           6        ::Debug Silo
# 1             233           6    ::officeupstairs
# 2             304          10         ::redsfinal
# 3             256           6           ::SouthA1
# 4             268          10       ::opheimletin
# ...           ...         ...                 ...
# 10779         438          16        ::postscript
# 10780         207          12         ::impatient
# 10781         188           8           ::opinion
# 10782         323           8          ::software
# 10783          18           1  ::untitled passage
#
# [8877 rows x 5 columns]

# %% [markdown]
# ## Export to a file

# %%
with open('twee.txt', 'w') as file:
    file.writelines(passages.passage)
